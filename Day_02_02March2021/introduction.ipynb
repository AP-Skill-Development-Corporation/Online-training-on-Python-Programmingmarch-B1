# %%
# cell 1

# %% [markdown]
# 10 + 11

# %% [markdown]
# # cell 3

# %% [markdown]
# Python 3.8.3 (tags/v3.8.3:6f8c832, May 13 2020, 22:20:19) [MSC v.1925 32 bit (Intel)] on win32
# Type "help", "copyright", "credits" or "license()"

# %%
12 + 65
# Out:
# 77

# %% [markdown]
# # Markdow Syntax
#
# in this file we are going to learn bacis **markdown syntax**
# ## Jupyter note book file basic short cuts
# Esc +  m ---> to conver code cell to markdow
#
# Esc +  y ---> to conver code cell to markdow
#
# Esc +  dd ---> to delete a cell
#
# #### Exicute a cell
#
#                --> shift + enter
#
#                --> Ctrl + enter
#
#                --> Alt + enter

# %% [markdown]
# #### Bold
# __Bold text__ or **Bold text type 2**
#
# ####  Italic
# _Italic_ oR *Italic text tyoe 2*
#
# #### Strikethrough
#
# ~~Strikethrough~~
#
# ----
# horizontal line or rule
# ***
# `code blocks`

# %% [markdown]
# ### List
#
# 1. Ordered List
#     1. list 1
#     2. list 2
#     3. list 3
#
# 2. Unordered List
#     - list 1
#     - list 2
#     - list 3
#
# ****
# - [X] python
# - [ ] R language
# - [ ] markdown
#
# ## Links
# Syntax `[msg](url)`
#
# [Git hub Link](https://github.com/AP-Skill-Development-Corporation/Online-training-on-Python-Programmingmarch-B1)
#
# [error Url](https://github.com/AP-Skill-Development-Cor)
#
#
# [link](https://github.com/GirishaDevara)
#
# ## Image
#
# Syntax `![msg](url)`
#
# ![apssdc image](attachment:68747470733a2f2f64726976652e676f6f676c652e636f6d2f75633f6578706f72743d646f776e6c6f61642669643d3135414b51365f2d42697857344b366d4c36525070684635454b58715946327a6a.png)
#
#
#
# #### image 2
# ![image](https://raw.githubusercontent.com/docker-library/docs/01c12653951b2fe592c1f93a13b4e289ada0e3a1/python/logo.png)
#
# `code blocke 23+56`

# %% [markdown]
# ### Tables
#
# | table column header | header2 | header 3|
# |---------------|---------|--------|
# | colunm data 1X1 | Colunm data 1X2| Colunm data 1X3 |
#
#
#  __Or__
#
#
# S.no | stundet name | Roll number | year
# ------|-------|------|-------
# 1 | **satya** | 101 | 2nd year
# 2 | ***divya***|102 | 3rd year

# %% [markdown]
# ![image2](data:image/jpeg;base64,...)

# %% [markdown]
# ## image with html tag
#
# <img src="https://raw.githubusercontent.com/docker-library/docs/01c12653951b2fe592c1f93a13b4e289ada0e3a1/python/logo.png" alt="python logo" width="50" height="60">
#
# `html
# <img src="https://raw.githubusercontent.com/docker-library/docs/01c12653951b2fe592c1f93a13b4e289ada0e3a1/python/logo.png" alt="python logo" width="50" height="60">`
